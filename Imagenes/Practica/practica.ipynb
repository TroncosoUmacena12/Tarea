# %% [markdown]
# CARGAR 3 IMAGENES

# %%
import cv2 
import matplotlib.pyplot as plt

imagen_bgr1 = cv2.imread('pose1.png')
imagen_bgr2 = cv2.imread('pose2.png')
imagen_bgr3 = cv2.imread('pose3.png')

imagen_RGB1 = cv2.cvtColor(imagen_bgr1, cv2.COLOR_BGR2RGB)
imagen_RGB2 = cv2.cvtColor(imagen_bgr2, cv2.COLOR_BGR2RGB)
imagen_RGB3 = cv2.cvtColor(imagen_bgr3, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.imshow(imagen_RGB1)
plt.title("Pose 1")

plt.subplot(1, 3, 2)
plt.imshow(imagen_RGB2)
plt.title("Pose 2")

plt.subplot(1, 3, 3)
plt.imshow(imagen_RGB3)
plt.title("Pose 3")

plt.show()

# %% [markdown]
# ESCALA EN GRISES

# %%
import cv2 
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'],[10,5]
img=cv2.imread('pose1.png',cv2.IMREAD_COLOR)

plt.subplot(141)
plt.title("Pose Original")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

plt.subplot(142)
plt.imshow(img[:,:,0],cmap='gray')
plt.title("Escala 1 gris")


plt.subplot(143)
plt.imshow(img[:,:,1],cmap='gray')
plt.title("Escala 2 gris")

plt.subplot(144)
plt.imshow(img[:,:,2],cmap='gray')
plt.title("Escala 3 gris")

plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt

imagen_bgr = cv2.imread('pose1.png')
imagen_bgr1 = cv2.imread('pose1.png')

imagen_RGB = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(12,4))

plt.subplot(1 ,4 ,1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')


plt.subplot(1, 4,2 )
plt.imshow(imagen_RGB[:,:,0],cmap='gray')
plt.title("Escala 1 gris")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(imagen_RGB[:,:,1],cmap='gray')
plt.title("Escala 2 gris")
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(imagen_RGB[:,:,2],cmap='gray')
plt.title("Escala 3 gris")
plt.axis('off')


plt.show()



plt.figure(figsize=(12, 4))

r = imagen_bgr[:, :, 2]
g = imagen_bgr[:, :, 1]
b = imagen_bgr[:, :, 0]

r_imgen = np.zeros_like(imagen_RGB)
r_imgen[:, :, 0] = r

g_imgen = np.zeros_like(imagen_RGB)
g_imgen[:, :, 1] = g

b_imgen = np.zeros_like(imagen_RGB)
b_imgen[:, :, 2] = b

plt.subplot(1, 4, 1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.title('Canal Rojo')
plt.imshow(r_imgen)
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Canal Verde')
plt.imshow(g_imgen)
plt.axis('off')

plt.subplot(1, 4, 4)
plt.title('Canal Azul')
plt.imshow(b_imgen)
plt.axis('off')

plt.show()



plt.figure(figsize=(12, 4))
b,g,r=cv2.split(imagen_bgr)
plt.subplot(1, 4, 1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.title('Canal Rojo')
plt.imshow(r,cmap='Reds')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Canal Verde')
plt.imshow(g,cmap='Greens')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.title('Canal Azul')
plt.imshow(b,cmap='Blues')
plt.axis('off')

plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt

imagen_bgr = cv2.imread('pose2.png')
imagen_bgr1 = cv2.imread('pose2.png')

imagen_RGB = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(12,4))

plt.subplot(1 ,4 ,1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')


plt.subplot(1, 4,2 )
plt.imshow(imagen_RGB[:,:,0],cmap='gray')
plt.title("Escala 1 gris")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(imagen_RGB[:,:,1],cmap='gray')
plt.title("Escala 2 gris")
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(imagen_RGB[:,:,2],cmap='gray')
plt.title("Escala 3 gris")
plt.axis('off')


plt.show()



plt.figure(figsize=(12, 4))

r = imagen_bgr[:, :, 2]
g = imagen_bgr[:, :, 1]
b = imagen_bgr[:, :, 0]

r_imgen = np.zeros_like(imagen_RGB)
r_imgen[:, :, 0] = r

g_imgen = np.zeros_like(imagen_RGB)
g_imgen[:, :, 1] = g

b_imgen = np.zeros_like(imagen_RGB)
b_imgen[:, :, 2] = b

plt.subplot(1, 4, 1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.title('Canal Rojo')
plt.imshow(r_imgen)
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Canal Verde')
plt.imshow(g_imgen)
plt.axis('off')

plt.subplot(1, 4, 4)
plt.title('Canal Azul')
plt.imshow(b_imgen)
plt.axis('off')

plt.show()



plt.figure(figsize=(12, 4))
b,g,r=cv2.split(imagen_bgr)
plt.subplot(1, 4, 1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.title('Canal Rojo')
plt.imshow(r,cmap='Reds')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Canal Verde')
plt.imshow(g,cmap='Greens')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.title('Canal Azul')
plt.imshow(b,cmap='Blues')
plt.axis('off')

plt.show()

# %%
import cv2 
import matplotlib.pyplot as plt

imagen_bgr = cv2.imread('pose3.png')
imagen_bgr1 = cv2.imread('pose3.png')

imagen_RGB = cv2.cvtColor(imagen_bgr, cv2.COLOR_BGR2RGB)


plt.figure(figsize=(12,4))

plt.subplot(1 ,4 ,1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')


plt.subplot(1, 4,2 )
plt.imshow(imagen_RGB[:,:,0],cmap='gray')
plt.title("Escala 1 gris")
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(imagen_RGB[:,:,1],cmap='gray')
plt.title("Escala 2 gris")
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(imagen_RGB[:,:,2],cmap='gray')
plt.title("Escala 3 gris")
plt.axis('off')


plt.show()



plt.figure(figsize=(12, 4))

r = imagen_bgr[:, :, 2]
g = imagen_bgr[:, :, 1]
b = imagen_bgr[:, :, 0]

r_imgen = np.zeros_like(imagen_RGB)
r_imgen[:, :, 0] = r

g_imgen = np.zeros_like(imagen_RGB)
g_imgen[:, :, 1] = g

b_imgen = np.zeros_like(imagen_RGB)
b_imgen[:, :, 2] = b

plt.subplot(1, 4, 1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.title('Canal Rojo')
plt.imshow(r_imgen)
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Canal Verde')
plt.imshow(g_imgen)
plt.axis('off')

plt.subplot(1, 4, 4)
plt.title('Canal Azul')
plt.imshow(b_imgen)
plt.axis('off')

plt.show()



plt.figure(figsize=(12, 4))
b,g,r=cv2.split(imagen_bgr)
plt.subplot(1, 4, 1)
plt.title("Pose Original")
plt.imshow(imagen_RGB)
plt.axis('off')

plt.subplot(1, 4, 2)
plt.title('Canal Rojo')
plt.imshow(r,cmap='Reds')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.title('Canal Verde')
plt.imshow(g,cmap='Greens')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.title('Canal Azul')
plt.imshow(b,cmap='Blues')
plt.axis('off')

plt.show()

# %% [markdown]
# SEGMENTACION

# %%
import cv2 
import matplotlib.pyplot as plt

img1=cv2.imread(x,cv2.IMREAD_COLOR)
 
plt.imshow(img1[:num1,:num2,:])
plt.title('Segmentaciones')
plt.show()
